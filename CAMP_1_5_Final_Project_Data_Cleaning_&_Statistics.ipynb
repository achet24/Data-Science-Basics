# %% [markdown]
# <a href="https://colab.research.google.com/github/achet24/Data-Science-Basics/blob/main/CAMP_1_5_Final_Project_Data_Cleaning_%26_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 📦 **Importing Libraries & Packages**

# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd

# %% [markdown]
# ### **⬆️ Uploading Files to Google Colab to Import Data**
# To upload a file, run the cell below and then choose the file on your desktop.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ead8e68a-1765-45ba-b151-1817861c75bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ead8e68a-1765-45ba-b151-1817861c75bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Then, import to the pandas dataframe. Make sure to change `nameoffile` to the name of the file that you uploaded. You will also want to change the name of the DataFrame to something that is representative of your dataset. In this case, change `dataset` to a more representative name.

# %%
#use this if your dataset is a csv

import io
disney = pd.read_csv(io.BytesIO(uploaded['DisneyMoviesDataset.csv']))

# %%
#use this if your dataset is a xlsx

import io
dataset = pd.read_excel(io.BytesIO(uploaded['nameoffile.xlsx']))

# %% [markdown]
# If you do not yet have a dataset for your final project, upload the [Disney Movies Dataset](https://drive.google.com/file/d/1pqnM7VJKZ4zM9fqTO5MFnxD1O0gVPhST/view?usp=sharing) and use it for this lesson. You will first need to download the dataset to your computer.

# %% [markdown]
# ## 🧐 **Try It 1: Data Cleaning & Exploration**
#
# Make a new code cell below and run the functions shown.
#
# <font color="green" > *Note: Be sure to change DATASET to the name you used to import your dataset to your Colab notebook.*
#
# ### DATASET.shape 		<font color="green" >→ describe the shape of the DataFrame
#
# ###DATASET.head(n)		<font color="green" >→ display the top n rows
#
# ###DATASET.info()		<font color="green" >→ display column types and missing values
#
# ###DATASET.describe()	<font color="green" >→ display summary statistics
#
# ###DATASET.dtypes <font color="green" >→ check the data types of each variable

# %%
disney.shape
# Out:
# (432, 32)

# %%
disney.head()
# Out:
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#                                         Release date  \
# 0                                   ['May 19, 1937']
# 1  ['December 21, 1937 ( Carthay Circle Theatre ,...
# 2  ['February 7, 1940 ( Center Theatre )', 'Febru...
# 3                              ['November 13, 1940']
# 4                                  ['June 20, 1941']
#
#                            Running time        Country Language  \
# 0  41 minutes (74 minutes 1966 release)  United States  English
# 1                            83 minutes  United States  English
# ...

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               432 non-null    int64
#  1   title                    432 non-null    object
#  2   Production company       392 non-null    object
#  3   Release date             431 non-null    object
#  4   Running time             422 non-null    object
#  5   Country                  428 non-null    object
#  6   Language                 430 non-null    object
#  7   Running time (int)       422 non-null    float64
#  8   Budget (float)           273 non-null    float64
#  9   Box office (float)       355 non-null    float64
#  10  Release date (datetime)  428 non-null    object
#  11  imdb                     416 non-null    float64
#  12  metascore                283 non-null    float64
#  13  rotten_tomatoes          361 non-null    object
# ...

# %%
disney.describe()
# Out:
#        Unnamed: 0  Running time (int)  Budget (float)  Box office (float)  \
# count  432.000000          422.000000    2.730000e+02        3.550000e+02
# mean   215.500000           97.305687    6.358861e+07        1.674014e+08
# std    124.851912           18.959487    7.163732e+07        2.749517e+08
# min      0.000000           40.000000    1.500000e+02        7.700000e+00
# 25%    107.750000           86.000000    1.000000e+07        9.850000e+06
# 50%    215.500000           96.000000    3.000000e+07        4.290000e+07
# 75%    323.250000          106.750000    1.000000e+08        1.865500e+08
# max    431.000000          168.000000    4.106000e+08        1.657000e+09
#
#              imdb   metascore
# count  416.000000  283.000000
# mean     6.545433   61.487633
# std      0.960937   16.562658
# min      1.500000   18.000000
# 25%      6.000000   49.000000
# 50%      6.600000   61.000000
# 75%      7.200000   73.000000
# max      8.700000   99.000000

# %%
disney.dtypes
# Out:
# Unnamed: 0                   int64
# title                       object
# Production company          object
# Release date                object
# Running time                object
# Country                     object
# Language                    object
# Running time (int)         float64
# Budget (float)             float64
# Box office (float)         float64
# Release date (datetime)     object
# imdb                       float64
# metascore                  float64
# rotten_tomatoes             object
# Directed by                 object
# Produced by                 object
# Written by                  object
# Based on                    object
# Starring                    object
# Music by                    object
# Distributed by              object
# Budget                      object
# Box office                  object
# Story by                    object
# Narrated by                 object
# Cinematography              object
# Edited by                   object
# ...

# %% [markdown]
# ## 👥 **Try It 2: Checking for duplicated rows (repeated data entries by error).**
#
# Make a new code cell below and run the functions shown.
#
# ###DATASET.duplicated()  <font color="green" >→ Check to see if any rows are duplicates
#
# ###DATASET.duplicated().sum() <font color="green" >→ add up the total number of rows that are duplicates
#
# ###DATASET.drop_duplicates() <font color="green" >→ DataFrame Method that removes duplicate rows.

# %%
disney.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 427    False
# 428    False
# 429    False
# 430    False
# 431    False
# Length: 432, dtype: bool

# %%
disney.duplicated().sum()
# Out:
# 0

# %%
disney.drop_duplicates()
# Out:
#      Unnamed: 0                            title  \
# 0             0          Academy Award Review of
# 1             1  Snow White and the Seven Dwarfs
# 2             2                        Pinocchio
# 3             3                         Fantasia
# 4             4             The Reluctant Dragon
# ..          ...                              ...
# 427         427                             Soul
# 428         428         Raya and the Last Dragon
# 429         429                          Cruella
# 430         430                    Jungle Cruise
# 431         431            The Beatles: Get Back
#
#                                     Production company  \
# 0                              Walt Disney Productions
# 1                              Walt Disney Productions
# 2                              Walt Disney Productions
# 3                              Walt Disney Productions
# 4                              Walt Disney Productions
# ...

# %% [markdown]
# ##  **✏️ Try It 3: Renaming Variables if Needed**
#
# Make a new code cell below. Try to rename one of your columns using the function shown.
#
# DATASET.rename(columns = {'OLD NAME':'NEW NAME'}, inplace = True)

# %%
disney.rename(columns = {'Running time':'Duration'}, inplace = True)
disney.head()
# Out:
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#                                         Release date  \
# 0                                   ['May 19, 1937']
# 1  ['December 21, 1937 ( Carthay Circle Theatre ,...
# 2  ['February 7, 1940 ( Center Theatre )', 'Febru...
# 3                              ['November 13, 1940']
# 4                                  ['June 20, 1941']
#
#                                Duration        Country Language  \
# 0  41 minutes (74 minutes 1966 release)  United States  English
# 1                            83 minutes  United States  English
# ...

# %% [markdown]
# ## 🗑 **Try It 4: Dropping/Deleting Columns and Rows**
#
# Make a new code cell below. Try out the functions shown with your dataset!
#
# DATASET.drop([‘COLUMN_NAME’], axis = 1, inplace = True)  <font color="green" >→ dropping a column(variable) from your dataset.
#
# DATASET2 = DATASET[['COLUMN NAME','COLUMN NAME2','COLUMN NAME3']] <font color="green" >→ another option is to save a new version of the dataset with only the selected columns you need for your analyses.
#
# DATASET.drop([‘ROW_NAME’], axis = 0, inplace = True) <font color="green" >→ dropping a row (observation) from your dataset. Remember that you need to be able to justify WHY you are deleting observations from a dataset.

# %%
disney2 = disney[['title', 'Duration', 'Language', 'imdb']]
disney2.head(10)
# Out:
#                              title                              Duration  \
# 0          Academy Award Review of  41 minutes (74 minutes 1966 release)
# 1  Snow White and the Seven Dwarfs                            83 minutes
# 2                        Pinocchio                            88 minutes
# 3                         Fantasia                           126 minutes
# 4             The Reluctant Dragon                            74 minutes
# 5                            Dumbo                            64 minutes
# 6                            Bambi                            70 minutes
# 7                   Saludos Amigos                            42 minutes
# 8        Victory Through Air Power                               65 min.
# 9             The Three Caballeros                            71 minutes
#
#                                Language  imdb
# 0                               English   7.2
# 1                               English   7.6
# ...

# %%
disney.drop(['rotten_tomatoes'], axis = 1, inplace = True)

# %% [markdown]
# ## 📊  **Try It 5: Converting Data Types**
#
# Make a new code cell below. Try to change the data types of one of your columns!
#
# DATASET['COL_NAME'] = DATASET['COL_NAME'].astype(DATA_TYPE) <font color="green" >→ Method to convert a DataFrame or Pandas Series to a specified data type.

# %%
disney['imdb'] = disney['imdb'].astype(object)
disney.dtypes
# Out:
# Unnamed: 0                   int64
# title                       object
# Production company          object
# Release date                object
# Duration                    object
# Country                     object
# Language                    object
# Running time (int)         float64
# Budget (float)             float64
# Box office (float)         float64
# Release date (datetime)     object
# imdb                        object
# metascore                  float64
# Directed by                 object
# Produced by                 object
# Written by                  object
# Based on                    object
# Starring                    object
# Music by                    object
# Distributed by              object
# Budget                      object
# Box office                  object
# Story by                    object
# Narrated by                 object
# Cinematography              object
# Edited by                   object
# Screenplay by               object
# ...

# %% [markdown]
# ## 🧵  **Try It 6: String Data**
#
# Make a new code cell below. Try out the following functions.
#
# DATASET[‘COL_NAME’] = DATASET[‘COL_NAME’].str.strip('CHAR_TO_REMOVE') <font color="green" >→ strip() = Removes spaces at the beginning and end, and removes any characters included inside parentheses.
#
#
#
# DATASET[‘COL_NAME’] = DATASET[‘COL_NAME’].str.replace('VALUE1', 'VALUE2')  <font color="green" > → replace() = Method to replace a value with another value

# %% [markdown]
# ## 🫥  **Try It 7: Missing Values**
#
# Make a new code cell below. Try out the following functions.
#
# DATASET.isna().sum(). <font color="green" >→ counts the total missing values
#
# DATASET['COL_NAME'].isna().sum(). <font color="green" >→ counts the total missing values for a given column
#
# DATASET[‘COL_NAME’] = DATASET[‘COL_NAME’].fillna('NA', inplace=True)  <font color="green" > → replace NaN with "NA" in a specified non-numerical column

# %%
disney.isna().sum()
# Out:
# Unnamed: 0                   0
# title                        0
# Production company          40
# Release date                 1
# Duration                    10
# Country                      4
# Language                     2
# Running time (int)          10
# Budget (float)             159
# Box office (float)          77
# Release date (datetime)      4
# imdb                        16
# metascore                  149
# Directed by                  1
# Produced by                 10
# Written by                 229
# Based on                   221
# Starring                    34
# Music by                    10
# Distributed by               3
# Budget                     156
# Box office                  73
# Story by                   293
# Narrated by                377
# Cinematography              90
# Edited by                   37
# Screenplay by              241
# Production companies       393
# Adaptation by              431
# Traditional                431
# ...

# %%
disney['Based on'] = disney['Based on'].fillna('NA', inplace=True)
disney['Based on'].head()
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: Based on, dtype: object

# %% [markdown]
# #📈  Data Visualizations!

# %%
#import seaborn library
import seaborn as sns

# %% [markdown]
# ## 📉 Try It 8: CORRELATIONS aka "relationships between continuous variables"
#
# Make a new code cell below and run the functions on your dataset!
#
# DATASET.corr(numeric_only = True) <font color="green"> → runs a correlation coefficient matrix for your dataset
#
# <font color="green"> To see your correlation coefficient matrix as a heatmap using Seaborn →
#
# sns.heatmap(DATASET.corr(numeric_only = True))
#
# sns.heatmap

# %%
disney.corr(numeric_only = True)
# Out:
#                     Unnamed: 0  Running time (int)  Budget (float)  \
# Unnamed: 0            1.000000            0.291015        0.575304
# Running time (int)    0.291015            1.000000        0.389359
# Budget (float)        0.575304            0.389359        1.000000
# Box office (float)    0.473870            0.278317        0.740025
# metascore            -0.089599           -0.011121        0.044219
#
#                     Box office (float)  metascore
# Unnamed: 0                    0.473870  -0.089599
# Running time (int)            0.278317  -0.011121
# Budget (float)                0.740025   0.044219
# Box office (float)            1.000000   0.322004
# metascore                     0.322004   1.000000

# %%
#import Matplotlib
import matplotlib.pyplot as plt

#to get data viz to show up inside our Google Colab
# %matplotlib inline

#We’ll also set the size of the figure
plt.rcParams['figure.figsize'] = (8.0, 6.0)

# %%
sns.heatmap(disney.corr(numeric_only = True))

sns.heatmap
# Out:
# <function seaborn.matrix.heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)>

# %% [markdown]
# ##🖥️ Matplotlib Basic Syntax
#
# plt.figure() <font color="green" >→  sets up a figure object
#
# plt.plot() <font color="green" >→  determines the type of plot we are creating and takes in the data needed
#
# plt.show() <font color="green" >→ shows the figure on screen
#
# -------------------
# ##Line Plot
# <font color="green" >Line graphs are used to track changes over short and long periods of time or to compare how things change over time relative to each other
#
# plt.figure()
#
# plt.plot(DATASET['X_COL_NAME'], DATASET['Y_COL_NAME'])
#
# plt.xlabel('LABEL1')
#
# plt.ylabel('LABEL2')
#
# plt.title('TITLE', fontsize = 22)
#
# plt.show()

# %%
plt.figure()

plt.plot(disney['Release date'], disney['Running time (int)'])

plt.xlabel('Year')

plt.ylabel('Length of film')

plt.title('Evolution film duration', fontsize = 22)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-aa3544543d11> in <cell line: 3>()
#       1 plt.figure()
#       2
# ----> 3 plt.plot(disney['Release date'], disney['Running time (int)'])
#       4
#       5 plt.xlabel('Year')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %% [markdown]
# -------------------
# ##Scatter Plot
#
# <font color="green"> A scatter plot shows the relationship between two variables
#
# plt.figure()
#
# plt.scatter(DATASET['X_COL_NAME'], DATASET['Y_COL_NAME'],
#   color = 'COLOR_NAME', s = 30)
#
# plt.xlabel('LABEL1')
#
# plt.ylabel('LABEL2')
#
# plt.title('TITLE', fontsize = 22)
#
# plt.show()

# %% [markdown]
# -------------------
# ##Histogram
# <font color="green" >This is a frequency count of a variable.
# A histogram is the graphical representation of data where data is grouped into continuous number ranges and each range corresponds to a vertical bar.
#
# <font color="green" >*Note: *bin value indicates the number of columns you want in your histogram.
#
# <font color="green" >Smaller bin value = less detailed = fatter columns = more data in each "bar" of the histogram
#
# <font color="green" >Bigger bin value = more detailed = skinnier columns = less data in each "bar" of the histogram
#
# plt.figure()
#
# plt.hist(DATASET['COL_NAME'], bins = 50, color='COLOR_NAME')
#
# plt.xlabel('LABEL1')
#
# plt.ylabel('LABEL2')
#
# plt.title('TITLE', fontsize = 22)
#
# plt.show()

# %% [markdown]
# -------------------
# ##Bar Chart
#
# <font color="green">A bar graph is the graphical representation of categorical data using rectangular bars where the length of each bar is proportional to the value they represent.
#
# plt.figure()
#
# plt.bar(DATASET['COL_NAME'].value_counts().index,
#
#  DATASET['SAME_COL_NAME'].value_counts().values)
#
# plt.xlabel('LABEL1')
#
# plt.ylabel('LABEL2')
#
# plt.title('TITLE', fontsize = 22)
#
# plt.show()

# %% [markdown]
# ## 📊 Try It 9: Make a Chart!
#
# In the code cell below, practice making at least one chart.
#
# Remember to think about what variables work best for each chart type.
#
# * 📈 Line plot -> this shows how numerical data changes over time. The y-axis should be a numerical variable (integer or float data type) and the x-axis should be a variable related to time (e.g., hours, days, months).
# * 📉 Scatter plot -> this shows the relationship between two continuous variables (float data type).
# * 📜 Histogram -> this shows the frequency distribution of a numerical variable (integer or float data type).
# * 📊 Bar chart -> helps represent categorical data. The variable type used for this graph should be object/string. It may also be an integer data type in some circumstances. For example, there might be 3 categories for fire hazard severity: 1, 2, and 3.

# %% [markdown]
# # 📁 Saving Dataframe as CSV file on DESKTOP
#
# from google.colab import files
#
# DATAFRAME.to_csv('DATAFRAME.csv', encoding = 'utf-8-sig')
#
# files.download('DATAFRAME.csv')
